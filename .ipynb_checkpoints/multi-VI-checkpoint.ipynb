# %%
import jax
import jaxlib

print("jax version:", jax.__version__)
print("jaxlib version:", jaxlib.__version__)

import scvi
import h5py
import anndata as ad
import pandas as pd
import scipy.sparse as sp
# Out:
# jax version: 0.4.35
# jaxlib version: 0.4.35

# %%
# atse_anndata = []
# with h5py.File("/Users/smriti/documents/Research_Knowles_Lab/scvi-tools-splicing/ann_data/ATSE_Anndata_Object_BRAIN_only_20241105_wLeafletFAPSIs.h5ad", "r") as file:
#     for attr, value in file.attrs.items():
#         print(f"{attr}: {value}")
#     def print_name(name):
#         print(name)
    
#     file.visit(print_name)

# with h5py.File("/Users/smriti/documents/Research_Knowles_Lab/scvi-tools-splicing/ann_data/GE_Anndata_Object_BRAIN_only_20241105.h5ad", "r") as file:
#     for attr, value in file.attrs.items():
#         print(f"{attr}: {value}")


# try:
#     with h5py.File('/Users/smriti/documents/Research_Knowles_Lab/scvi-tools-splicing/ann_data/ATSE_Anndata_Object_BRAIN_only_20241105_wLeafletFAPSIs.h5ad', 'r') as f:
#         for key in f.keys():
#             print(f"Dataset name: {key}")
#             # Try to read individual datasets
#             try:
#                 data = f[key][:]
#                 print(data)
#             except Exception as e:
#                 print(f"Error reading dataset {key}: {e}")
# except Exception as e:
#     print(f"Error opening file: {e}")
    
atse_anndata = ad.read_h5ad('/Users/smriti/documents/Research_Knowles_Lab/multivi_tools_splicing/ann_data/ATSE_Anndata_Object_BRAIN_only_20241105_wLeafletFAPSIs.h5ad')

# %%
atse_anndata.var
# Out:
#        junction_id_index                  junction_id                gene_id  \
# 0                      0  chr10_100080130_100080856_+  ENSMUSG00000019966.18
# 1                      1  chr10_100080130_100087346_+  ENSMUSG00000019966.18
# 2                      2  chr10_100080940_100087346_+  ENSMUSG00000019966.18
# 3                      3  chr10_100478022_100485050_-  ENSMUSG00000036676.14
# 4                      4  chr10_100478022_100487161_-  ENSMUSG00000036676.14
# ...                  ...                          ...                    ...
# 54071              54071     chrY_90793417_90816348_+   ENSMUSG00000096768.7
# 54072              54072     chrY_90793680_90816348_+   ENSMUSG00000096768.7
# 54073              54073         chrY_910586_910685_+  ENSMUSG00000056673.14
# 54074              54074         chrY_927439_927602_+  ENSMUSG00000056673.14
# 54075              54075         chrY_927439_927709_+  ENSMUSG00000056673.14
#
#        num_cells_with_junc  total_read_counts  Cluster  CountJuncs gene_name  \
# 0                     3937             177614    35178           3      Kitl
# 1                     2691             113292    35178           3      Kitl
# 2                     3809             158127    35178           3      Kitl
# 3                      556               7317    37286           4     Tmtc3
# 4                     2196              36551    37286           4     Tmtc3
# ...                    ...                ...      ...         ...       ...
# 54071                31512            1589647    62109           2   Gm47283
# 54072                12558             479395    62109           2   Gm47283
# 54073                  233               4867    62095           4     Kdm5d
# 54074                   21               1048    62096           2     Kdm5d
# 54075                  137               1909    62096           2     Kdm5d
#
#        old_index
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 54071      63566
# 54072      63567
# 54073      63569
# 54074      63570
# 54075      63571
#
# [54076 rows x 9 columns]

# %%
atse_anndata.obs
# Out:
#                                    cell_id  age  batch   cell_ontology_class  \
# cell_id_for_index
# A1_B000826           A1-B000826-3_39_F-1-1   3m      1       microglial cell
# A1_B001176           A1-B001176-3_56_F-1-1   3m      1       microglial cell
# A1_B003279           A1-B003279-3_38_F-1-1   3m      1       microglial cell
# A1_B003281           A1-B003281-3_39_F-1-1   3m      1       microglial cell
# A1_B003290           A1-B003290-3_38_F-1-1   3m      1        ependymal cell
# ...                                    ...  ...    ...                   ...
# P9_B003921            P9_B003921_S369_L001  24m      1       microglial cell
# P9_D045315         P9_D045315_B008285_S369  18m      1       microglial cell
# P9_D045318         P9_D045318_B008591_S369  18m      1       microglial cell
# P9_D045372         P9_D045372_B009292_S177  18m      1  neuroepithelial cell
# P9_D045853         P9_D045853_B009304_S165  18m      1       microglial cell
#
#                   method mouse.id     sex             tissue  \
# cell_id_for_index
# A1_B000826          facs   3_39_F  female      Brain_Myeloid
# A1_B001176          facs   3_56_F  female      Brain_Myeloid
# A1_B003279          facs   3_38_F  female      Brain_Myeloid
# A1_B003281          facs   3_39_F  female      Brain_Myeloid
# A1_B003290          facs   3_38_F  female  Brain_Non-Myeloid
# ...                  ...      ...     ...                ...
# P9_B003921          facs  24_59_M    male      Brain_Myeloid
# P9_D045315          facs  18_45_M    male      Brain_Myeloid
# P9_D045318          facs  18_45_M    male      Brain_Myeloid
# P9_D045372          facs  18_45_M    male  Brain_Non-Myeloid
# P9_D045853          facs  18_46_F  female      Brain_Myeloid
#
#                    old_cell_id_index  cell_clean  cell_id_index  \
# cell_id_for_index
# A1_B000826                         6  A1_B000826              6
# A1_B001176                         9  A1_B001176              9
# A1_B003279                        22  A1_B003279             22
# A1_B003281                        23  A1_B003281             23
# A1_B003290                        25  A1_B003290             25
# ...                              ...         ...            ...
# P9_B003921                    107554  P9_B003921         106828
# P9_D045315                    107559  P9_D045315         106833
# P9_D045318                    107560  P9_D045318         106834
# P9_D045372                    107562  P9_D045372         106836
# P9_D045853                    107564  P9_D045853         106838
#
#                   subtissue_clean     cell_type_grouped
# cell_id_for_index
# A1_B000826                 Cortex             MICROGLIA
# A1_B001176               Striatum             MICROGLIA
# A1_B003279             Cerebellum             MICROGLIA
# A1_B003281            Hippocampus             MICROGLIA
# A1_B003290               Striatum            GLIAL CELL
# ...                           ...                   ...
# P9_B003921                 Cortex             MICROGLIA
# P9_D045315            Hippocampus             MICROGLIA
# P9_D045318               Striatum             MICROGLIA
# P9_D045372                 Cortex  NEUROEPITHELIAL CELL
# P9_D045853                 Cortex             MICROGLIA
#
# [19942 rows x 13 columns]

# %%
ge_anndata = ad.read_h5ad('/Users/smriti/documents/Research_Knowles_Lab/multivi_tools_splicing/ann_data/GE_Anndata_Object_BRAIN_only_20241105.h5ad')

# %%
ge_anndata.var
# Out:
#                n_cells mouse_gene_name  highly_variable     means  \
# index
# 0610005C13Rik     3939   0610005C13Rik            False  0.071325
# 0610007C21Rik    61891   0610007C21Rik            False  0.989017
# 0610007L01Rik    36115   0610007L01Rik            False  0.394134
# 0610007N19Rik    19591   0610007N19Rik            False  0.116377
# 0610007P08Rik    12581   0610007P08Rik            False  0.093049
# ...                ...             ...              ...       ...
# Zyg11a             276          Zyg11a            False  0.001733
# Zyg11b           23165          Zyg11b            False  0.192814
# Zyx              58021             Zyx            False  0.973926
# Zzef1            26577           Zzef1            False  0.289696
# Zzz3             23403            Zzz3            False  0.199683
#
#                dispersions  dispersions_norm
# index
# 0610005C13Rik     2.199756          0.159221
# 0610007C21Rik     2.088374         -0.574611
# 0610007L01Rik     1.690291         -0.792026
# 0610007N19Rik     1.506559         -0.504745
# 0610007P08Rik     1.590694         -0.424158
# ...                    ...               ...
# Zyg11a            1.983747         -0.047680
# Zyg11b            1.818861         -0.205613
# Zyx               2.496800         -0.155623
# Zzef1             2.088026          0.052202
# Zzz3              1.942793         -0.086907
#
# [22966 rows x 6 columns]

# %%
ge_anndata.obs
# Out:
#                   FACS.selection  age                   cell  \
# cell_id_for_index
# A1_B000826                   nan   3m  A1.B000826.3_39_F.1.1
# A1_B001176                   nan   3m  A1.B001176.3_56_F.1.1
# A1_B003279                   nan   3m  A1.B003279.3_38_F.1.1
# A1_B003281                   nan   3m  A1.B003281.3_39_F.1.1
# A1_B003290                   nan   3m  A1.B003290.3_38_F.1.1
# ...                          ...  ...                    ...
# P9_B003921             Microglia  24m             P9_B003921
# P9_D045315             Microglia  18m             P9_D045315
# P9_D045318             Microglia  18m             P9_D045318
# P9_D045372               Neurons  18m             P9_D045372
# P9_D045853             Microglia  18m             P9_D045853
#
#                     cell_ontology_class cell_ontology_id free_annotation  \
# cell_id_for_index
# A1_B000826              microglial cell       CL:0000129             nan
# A1_B001176              microglial cell       CL:0000129             nan
# A1_B003279              microglial cell       CL:0000129             nan
# A1_B003281              microglial cell       CL:0000129             nan
# A1_B003290               ependymal cell       CL:0000127        Ependyma
# ...                                 ...              ...             ...
# P9_B003921              microglial cell              nan             nan
# P9_D045315              microglial cell              nan             nan
# P9_D045318              microglial cell              nan             nan
# P9_D045372         neuroepithelial cell              nan             nan
# P9_D045853              microglial cell              nan             nan
#
#                   method mouse.id     sex     subtissue  ... n_genes  \
# cell_id_for_index                                        ...
# A1_B000826          facs   3_39_F  female        Cortex  ...    1887
# A1_B001176          facs   3_56_F  female      Striatum  ...    2257
# A1_B003279          facs   3_38_F  female    Cerebellum  ...    1091
# A1_B003281          facs   3_39_F  female   Hippocampus  ...    1930
# A1_B003290          facs   3_38_F  female      Striatum  ...    3345
# ...                  ...      ...     ...           ...  ...     ...
# P9_B003921          facs  24_59_M    male        Cortex  ...    1457
# P9_D045315          facs  18_45_M    male  Hippocampus   ...    1974
# P9_D045318          facs  18_45_M    male     Striatum   ...    2120
# P9_D045372          facs  18_45_M    male       Cortex   ...     776
# P9_D045853          facs  18_46_F  female       Cortex   ...    1365
#
#                      n_counts  cell_clean                  cell_id batch  \
# cell_id_for_index
# A1_B000826           680300.0  A1_B000826    A1-B000826-3_39_F-1-1     1
# A1_B001176           989907.0  A1_B001176    A1-B001176-3_56_F-1-1     1
# A1_B003279           670229.0  A1_B003279    A1-B003279-3_38_F-1-1     1
# A1_B003281           719168.0  A1_B003281    A1-B003281-3_39_F-1-1     1
# A1_B003290           379820.0  A1_B003290    A1-B003290-3_38_F-1-1     1
# ...                       ...         ...                      ...   ...
# P9_B003921         18500472.0  P9_B003921     P9_B003921_S369_L001     1
# P9_D045315           852807.0  P9_D045315  P9_D045315_B008285_S369     1
# P9_D045318          1214492.0  P9_D045318  P9_D045318_B008591_S369     1
# P9_D045372             6919.0  P9_D045372  P9_D045372_B009292_S177     1
# P9_D045853          1060695.0  P9_D045853  P9_D045853_B009304_S165     1
#
#                    old_cell_id_index  cell_id_index  subtissue_clean  \
# cell_id_for_index
# A1_B000826                         6              6           Cortex
# A1_B001176                         9              9         Striatum
# A1_B003279                        22             22       Cerebellum
# A1_B003281                        23             23      Hippocampus
# A1_B003290                        25             25         Striatum
# ...                              ...            ...              ...
# P9_B003921                    107554         106828           Cortex
# P9_D045315                    107559         106833      Hippocampus
# P9_D045318                    107560         106834         Striatum
# P9_D045372                    107562         106836           Cortex
# P9_D045853                    107564         106838           Cortex
#
#                       cell_type_grouped leiden
# cell_id_for_index
# A1_B000826                    MICROGLIA      4
# A1_B001176                    MICROGLIA      4
# A1_B003279                    MICROGLIA      4
# A1_B003281                    MICROGLIA      4
# A1_B003290                   GLIAL CELL     22
# ...                                 ...    ...
# P9_B003921                    MICROGLIA      4
# P9_D045315                    MICROGLIA      4
# P9_D045318                    MICROGLIA      0
# P9_D045372         NEUROEPITHELIAL CELL     26
# P9_D045853                    MICROGLIA      0
#
# [19942 rows x 21 columns]

# %% [markdown]
# 1. Preparing var data. As per the AnnData used in MultiVI, we have ID, modality, and n_cells with the index corresponding
# to the exact data point (gene or junction id)

# %%
gene_expr_var = pd.DataFrame({
    'ID': ge_anndata.var['mouse_gene_name'],
    'modality': 'Gene_Expression',
    'n_cells': ge_anndata.var['n_cells']
})
gene_expr_var.index = ge_anndata.var.index

# %%
splicing_var = pd.DataFrame({
    'ID': atse_anndata.var['junction_id'],
    'modality': 'Splicing',
    'n_cells': atse_anndata.var['num_cells_with_junc']
})
splicing_var.index = atse_anndata.var.index

# %%
combined_var = pd.concat([gene_expr_var, splicing_var])

# %% [markdown]
# 2. Preparing obs data.

# %%
combined_obs = pd.DataFrame({
    'batch_id': atse_anndata.obs['batch'],
    'modality': 'paired'
})
combined_obs.index = atse_anndata.obs.index

# %% [markdown]
# 3. Getting Count Data

# %%
splicing_counts = atse_anndata.layers['junc_ratio']
gene_expr_counts = ge_anndata.layers['raw_counts']
combined_counts = sp.hstack([gene_expr_counts, splicing_counts])

# %%
combined_adata = ad.AnnData(
    X=combined_counts,
    obs=combined_obs,
    var=combined_var
)

# %%
print(combined_adata)
# Out:
# AnnData object with n_obs × n_vars = 19942 × 77042
#     obs: 'batch_id', 'modality'
#     var: 'ID', 'modality', 'n_cells'

# %%
combined_adata.var
# Out:
#                                      ID         modality  n_cells
# 0610005C13Rik             0610005C13Rik  Gene_Expression     3939
# 0610007C21Rik             0610007C21Rik  Gene_Expression    61891
# 0610007L01Rik             0610007L01Rik  Gene_Expression    36115
# 0610007N19Rik             0610007N19Rik  Gene_Expression    19591
# 0610007P08Rik             0610007P08Rik  Gene_Expression    12581
# ...                                 ...              ...      ...
# 54071          chrY_90793417_90816348_+         Splicing    31512
# 54072          chrY_90793680_90816348_+         Splicing    12558
# 54073              chrY_910586_910685_+         Splicing      233
# 54074              chrY_927439_927602_+         Splicing       21
# 54075              chrY_927439_927709_+         Splicing      137
#
# [77042 rows x 3 columns]

# %%
combined_adata.obs
# Out:
#                    batch_id modality
# cell_id_for_index
# A1_B000826                1   paired
# A1_B001176                1   paired
# A1_B003279                1   paired
# A1_B003281                1   paired
# A1_B003290                1   paired
# ...                     ...      ...
# P9_B003921                1   paired
# P9_D045315                1   paired
# P9_D045318                1   paired
# P9_D045372                1   paired
# P9_D045853                1   paired
#
# [19942 rows x 2 columns]

# %%
combined_adata.write("/Users/smriti/documents/Research_Knowles_Lab/multivi_tools_splicing/ann_data/TMS_BRAINONLY_Combined_GE_ATSE.h5ad")
